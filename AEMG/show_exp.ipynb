# %%
import pandas as pd

# %%
data = pd.read_csv('out_exp.txt', sep=",", header=None)
# data.columns = ["a", "b", "c", "etc."]

# %%
pd.set_option('display.max_rows', None)

# %%
data.sort_values(by=[3], ascending= False)
# Out:
#                                         0     1    2         3
# 173                   1e2x1&2&bistable10k   987  900  0.911854
# 172                   1e2x1&1&bistable10k   987  808  0.818642
# 64                     1e2x1&1&bistable1k   999  805  0.805806
# 159                   1e1x1&2&bistable10k   994  772  0.776660
# 242                  1e1x1&1&bistable100k   752  562  0.747340
# 158                   1e1x1&1&bistable10k   982  702  0.714868
# 51                     1e1x1&2&bistable1k   989  660  0.667341
# 71     100_001_1e2x0_001_111&2&bistable1k   989  649  0.656218
# 95         100_001_1e2x0_001&2&bistable1k   986  640  0.649087
# 50                     1e1x1&1&bistable1k   994  626  0.629779
# 70     100_001_1e2x0_001_111&1&bistable1k   991  624  0.629667
# 94         100_001_1e2x0_001&1&bistable1k   990  609  0.615152
# 131                   1e3x1&2&bistable10k   978  592  0.605317
# 249                  1e2x1&1&bistable100k   907  545  0.600882
# ...
